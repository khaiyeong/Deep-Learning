# %% [markdown]
# # <font color="#0b486b">  FIT5215: Deep Learning (2025) - Assignment 2 (Section II)</font>
# ***
# *CE/Lecturer (Clayton):*  **Dr Trung Le** | trunglm@monash.edu <br/>
# *Lecturer (Clayton):* **A/Prof Zongyuan Ge** | zongyuan.ge@monash.edu <br/>
# *Lecturer (Malaysia):*  **Dr Arghya Pal** | arghya.pal@monash.edu <br/>
#  <br/>
# *Head Tutor 3181:*  **Ms Ruda Nie H** |  \[RudaNie.H@monash.edu \] <br/>
# *Head Tutor 5215:*  **Ms Leila Mahmoodi** |  \[leila.mahmoodi@monash.edu \]
#
# <br/> <br/>
# Faculty of Information Technology, Monash University, Australia
# ***

# %% [markdown]
# # <font color="#0b486b">  Student Information</font>
# ***
# Surname: **[Chew]**  <br/>
# Firstname: **[Khai Yeong ]**    <br/>
# Student ID: **[36487813 ]**    <br/>
# Email: **[kche0264@student.monash.edu ]**    <br/>
# Your tutorial time: **[Tuesday 8-10pm Malaysia ]**    <br/>
# ***

# %% [markdown]
# # <font color="0b486b">Assignment 2 – Deep Learning for Sequential Data</font>
# ### Due: <font color="red">11:55pm Sunday, 26 October 2025</font> (FIT5215)
#
# #### <font color="red">Important note:</font> This is an **individual** assignment. It contributes **20%** to your final mark. Read the assignment instructions carefully.

# %% [markdown]
# ## <font color="#0b486b">Assignment 2's Organization</font>
# This assignment 2 has two (2) sections:
# - Section 1: Fundamentals of RNNs (10 marks).
# - Section 2: Deep Learning for Sequential Data (90 marks). This section is further divided into 4 parts.
#
# The assignment 2 is organized in three (3) notebooks.
# - Notebook 1 ([link](https://colab.research.google.com/drive/1hTS6bWz6gU-lvi1qkIhrtQnJ3tzxRPFK?usp=sharing
# )) [Total: 30 marks] includes Section 1 as well as Part 1 and Part 2 of Section 2.
# - Notebook 2 ([link](https://colab.research.google.com/drive/1m0mh9Mk4-AKEhgAHRwQdl5mc0x7SF7Tv?usp=sharing)) [Total: 40 marks] includes Part 3 of Section 2.
# - Notebook 3 (this notebook) [Total: 30 marks] includes Part 4 of Section 2.

# %% [markdown]
# ## <font color="#0b486b">What to submit</font>
#
# This assignment is to be completed individually and submitted to Moodle unit site. **By the due date, you are required to submit one  <font color="red; font-weight:bold">single zip file, named xxx_assignment02_solution.zip</font> where `xxx` is your student ID, to the corresponding Assignment (Dropbox) in Moodle**. You can use Google Colab to do Assignment 2 but you need to save it to an `*.ipynb` file to submit to the unit Moodle.
#
# **More importantly, if you use Google Colab to do this assignment, you need to first make a copy of this notebook on your Google drive**.

# %% [markdown]
# ***For example, if your student ID is <font color="red; font-weight:bold">12356</font>, then gather all of your assignment solutions to a folder, create a zip file named <font color="red; font-weight:bold">123456_assignment02_solution.zip</font> and submit this file.***

# %% [markdown]
# Within this zip folder, you **must** submit the following files <u>for each part</u>:
# 1.	**`FIT5215_DeepLearning_Assignment2_Official[Main].ipynb`**:  this is your Python notebook solution source file.
# 1.	**`FIT5215_DeepLearning_Assignment2_Official[Main].html`**: this is the output of your Python notebook solution *exported* in HTML format.
# 1. **`FIT5215_DeepLearning_Assignment2_Official[RNNs].ipynb`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[RNNs].html`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[Transformers].ipynb`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[Transformers].html`**
# 1.	Any **extra files or folder** needed to complete your assignment (e.g., images used in your answers).

# %% [markdown]
# ## Section 2: Deep Learning for Sequential Data

# %% [markdown]
# ### <font color="#0b486b">Set random seeds</font>

# %% [markdown]
# We need to install the package datasets for creating BERT datasets.

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# We start with importing PyTorch and NumPy and setting random seeds for PyTorch and NumPy. You can use any seeds you prefer.

# %%
import os
import torch
import random
import requests
import pandas as pd
import numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from transformers import BertTokenizer
import os
from six.moves.urllib.request import urlretrieve
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def seed_all(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
seed_all(seed=1234)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## <font color="#0b486b">Download and preprocess the data</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold"><span></div>

# %% [markdown]
# The dataset we use for this assignment is a question classification dataset for which the training set consists of $5,500$ questions belonging to 6 coarse question categories including:
# - abbreviation (ABBR),
# - entity (ENTY),
# - description (DESC),
# - human (HUM),
# - location (LOC) and
# - numeric (NUM).
#
# In this assignment, we will utilize a subset of this dataset, containing $2,000$ questions for training and validation. We will use 80% of those 2000 questions for trainning and the rest for validation.

# %% [markdown]
# Preprocessing data is a crucial initial step in any machine learning or deep learning project. The *TextDataManager* class simplifies the process by providing functionalities to download and preprocess data specifically designed for the subsequent questions in this assignment. It is highly recommended to gain a comprehensive understanding of the class's functionality by **carefully reading** the content provided in the *TextDataManager* class before proceeding to answer the questions.

# %%
class DataManager:
    """
    This class manages and preprocesses a simple text dataset for a sentence classification task.

    Attributes:
        verbose (bool): Controls verbosity for printing information during data processing.
        max_sentence_len (int): The maximum length of a sentence in the dataset.
        str_questions (list): A list to store the string representations of the questions in the dataset.
        str_labels (list): A list to store the string representations of the labels in the dataset.
        numeral_labels (list): A list to store the numerical representations of the labels in the dataset.
        maxlen (int): Maximum length for padding sequences. Sequences longer than this length will be truncated,
            and sequences shorter than this length will be padded with zeros. Defaults to 50.
        numeral_data (list): A list to store the numerical representations of the questions in the dataset.
        random_state (int): Seed value for random number generation to ensure reproducibility.
            Set this value to a specific integer to reproduce the same random sequence every time. Defaults to 6789.
        random (np.random.RandomState): Random number generator object initialized with the given random_state.
            It is used for various random operations in the class.

    Methods:
        maybe_download(dir_name, file_name, url, verbose=True):
            Downloads a file from a given URL if it does not exist in the specified directory.
            The directory and file are created if they do not exist.

        read_data(dir_name, file_names):
            Reads data from files in a directory, preprocesses it, and computes the maximum sentence length.
            Each file is expected to contain rows in the format "<label>:<question>".
            The labels and questions are stored as string representations.

        manipulate_data():
            Performs data manipulation by tokenizing, numericalizing, and padding the text data.
            The questions are tokenized and converted into numerical sequences using a tokenizer.
            The sequences are padded or truncated to the maximum sequence length.

        train_valid_test_split(train_ratio=0.9):
            Splits the data into training, validation, and test sets based on a given ratio.
            The data is randomly shuffled, and the specified ratio is used to determine the size of the training set.
            The string questions, numerical data, and numerical labels are split accordingly.
            TensorFlow `Dataset` objects are created for the training and validation sets.


    """

    def __init__(self, verbose=True, random_state=6789):
        self.verbose = verbose
        self.max_sentence_len = 0
        self.str_questions = list()
        self.str_labels = list()
        self.numeral_labels = list()
        self.numeral_data = list()
        self.random_state = random_state
        self.random = np.random.RandomState(random_state)

    @staticmethod
    def maybe_download(dir_name, file_name, url, verbose=True):
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
        if not os.path.exists(os.path.join(dir_name, file_name)):
            urlretrieve(url + file_name, os.path.join(dir_name, file_name))
        if verbose:
            print("Downloaded successfully {}".format(file_name))

    def read_data(self, dir_name, file_names):
        self.str_questions = list()
        self.str_labels = list()
        for file_name in file_names:
            file_path= os.path.join(dir_name, file_name)
            with open(file_path, "r", encoding="latin-1") as f:
                for row in f:
                    row_str = row.split(":")
                    label, question = row_str[0], row_str[1]
                    question = question.lower()
                    self.str_labels.append(label)
                    self.str_questions.append(question[0:-1])
                    if self.max_sentence_len < len(self.str_questions[-1]):
                        self.max_sentence_len = len(self.str_questions[-1])

        # turns labels into numbers
        le = preprocessing.LabelEncoder()
        le.fit(self.str_labels)
        self.numeral_labels = np.array(le.transform(self.str_labels))
        self.str_classes = le.classes_
        self.num_classes = len(self.str_classes)
        if self.verbose:
            print("\nSample questions and corresponding labels... \n")
            print(self.str_questions[0:5])
            print(self.str_labels[0:5])

    def manipulate_data(self):
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        vocab = self.tokenizer.get_vocab()
        self.word2idx = {w: i for i, w in enumerate(vocab)}
        self.idx2word = {i:w for w,i in self.word2idx.items()}
        self.vocab_size = len(self.word2idx)

        token_ids = []
        num_seqs = []
        for text in self.str_questions:  # iterate over the list of text
          text_seqs = self.tokenizer.tokenize(str(text))  # tokenize each text individually
          # Convert tokens to IDs
          token_ids = self.tokenizer.convert_tokens_to_ids(text_seqs)
          # Convert token IDs to a tensor of indices using your word2idx mapping
          seq_tensor = torch.LongTensor(token_ids)
          num_seqs.append(seq_tensor)  # append the tensor for each sequence

        # Pad the sequences and create a tensor
        if num_seqs:
          self.numeral_data = pad_sequence(num_seqs, batch_first=True)  # Pads to max length of the sequences
          self.num_sentences, self.max_seq_len = self.numeral_data.shape

    def train_valid_test_split(self, train_ratio=0.8, test_ratio = 0.1):
        train_size = int(self.num_sentences*train_ratio) +1
        test_size = int(self.num_sentences*test_ratio) +1
        valid_size = self.num_sentences - (train_size + test_size)
        data_indices = list(range(self.num_sentences))
        random.shuffle(data_indices)
        self.train_str_questions = [self.str_questions[i] for i in data_indices[:train_size]]
        self.train_numeral_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_data = self.numeral_data[data_indices[:train_size]]
        train_set_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_labels = torch.from_numpy(train_set_labels)
        train_set = torch.utils.data.TensorDataset(train_set_data, train_set_labels)
        self.test_str_questions = [self.str_questions[i] for i in data_indices[-test_size:]]
        self.test_numeral_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_data = self.numeral_data[data_indices[-test_size:]]
        test_set_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_labels = torch.from_numpy(test_set_labels)
        test_set = torch.utils.data.TensorDataset(test_set_data, test_set_labels)
        self.valid_str_questions = [self.str_questions[i] for i in data_indices[train_size:-test_size]]
        self.valid_numeral_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_data = self.numeral_data[data_indices[train_size:-test_size]]
        valid_set_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_labels = torch.from_numpy(valid_set_labels)
        valid_set = torch.utils.data.TensorDataset(valid_set_data, valid_set_labels)
        self.train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
        self.test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
        self.valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)

# %%
print('Loading data...')
DataManager.maybe_download("data", "train_2000.label", "http://cogcomp.org/Data/QA/QC/")

dm = DataManager()
dm.read_data("data/", ["train_2000.label"])
# Out:
# Loading data...
# Downloaded successfully train_2000.label
#
# Sample questions and corresponding labels...
#
# ['manner how did serfdom develop in and then leave russia ?', 'cremat what films featured the character popeye doyle ?', "manner how can i find a list of celebrities ' real names ?", 'animal what fowl grabs the spotlight after the chinese year of the monkey ?', 'exp what is the full form of .com ?']
# ['DESC', 'ENTY', 'DESC', 'ENTY', 'ABBR']

# %%
dm.manipulate_data()
dm.train_valid_test_split(train_ratio=0.8, test_ratio = 0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
for x, y in dm.train_loader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([64, 36]) torch.Size([64])

# %% [markdown]
# We now declare the `BaseTrainer` class, which will be used later to train the subsequent deep learning models for text data.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class BaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for i, data in enumerate(self.train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for data in loader:
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# ## <font color="#0b486b">Part 4: Transformer-based models for sequence modeling and neural embedding</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 30 marks]<span></div>

# %% [markdown]
# #### <font color="red">**Question 4.1**</font>
#
# **Implement the multi-head attention module of the Transformer for the text classification problem. The provided code is from our tutorial. In this part, we only use the output of the Transformer encoder for the classification task. For further information on the Transformer model, refer to [this paper](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf).**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# Below is the code of `MultiHeadSelfAttention`, `PositionWiseFeedForward`, `PositionalEncoding`, and `EncoderLayer`.

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        # Ensure that the model dimension (d_model) is divisible by the number of heads
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        # Initialize dimensions
        self.d_model = d_model # Model's dimension
        self.num_heads = num_heads # Number of attention heads
        self.d_k = d_model // num_heads # Dimension of each head's key, query, and value

        # Linear layers for transforming inputs
        self.W_q = nn.Linear(d_model, d_model) # Query transformation
        self.W_k = nn.Linear(d_model, d_model) # Key transformation
        self.W_v = nn.Linear(d_model, d_model) # Value transformation
        self.W_o = nn.Linear(d_model, d_model) # Output transformation

    def scaled_dot_product_attention(self, Q, K, V):
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        # Apply mask if provided (useful for preventing attention to certain parts like padding)
        #if mask is not None:
            #attn_scores = attn_scores.masked_fill(mask == 0, -1e9)

        # Softmax is applied to obtain attention probabilities
        attn_probs = torch.softmax(attn_scores, dim=-1)

        # Multiply by values to obtain the final output
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        # Reshape the input to have num_heads for multi-head attention
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        # Combine the multiple heads back to original shape
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V):
        # Apply linear transformations and split heads
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        # Perform scaled dot-product attention
        attn_output = self.scaled_dot_product_attention(Q, K, V)

        # Combine heads and apply output transformation
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_output = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# %% [markdown]
# Your task is to develop `TransformerClassifier` in which we input the embedding with the shape `[batch_size, seq_len, embed_dim]` to some `EncoderLayer` (i.e., num_layers specifies the number of EncoderLayer) and then compute the average of all token embeddings (i.e., `[batch_size, seq_len, embed_dim]`) across the `seq_len`. Finally, on the top of this average embedding, we build up a linear layer for making predictions.

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, num_layers, dropout_rate=0.2, data_manager = None):
        super(TransformerClassifier, self).__init__()
        self.vocab_size = data_manager.vocab_size
        self.num_classes = data_manager.num_classes
        self.embed_dim = embed_dim
        self.max_seq_len = data_manager.max_seq_len
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate

    def build(self):
        #Insert your code here
        #Embeddings
        self.embedding = nn.Embedding(self.vocab_size, self.embed_dim)
        # Positional encoding
        self.pos_encoder = PositionalEncoding(self.embed_dim, self.max_seq_len)

        # Stack of encoder layers
        self.encoder_layers = nn.ModuleList(
            [EncoderLayer(self.embed_dim, self.num_heads, self.ff_dim, self.dropout_rate)
             for _ in range(self.num_layers)]
        )

        #dropout and classifier
        self.final_dropout = nn.Dropout(self.dropout_rate)
        self.fclayer = nn.Linear(self.embed_dim, self.num_classes)

    def forward(self, x):
        #Insert your code here
        x = self.embedding(x)
        x = self.pos_encoder(x)
        for layer in self.encoder_layers:
            x = layer(x)
        pooled = torch.mean(x, dim=1)
        pooled = self.final_dropout(pooled)
        output = self.fclayer(pooled)
        return output

# %%
transformer = TransformerClassifier(embed_dim=512, num_heads=8, ff_dim=2048, num_layers=12, dropout_rate=0.1, data_manager= dm)
transformer.build()
transformer = transformer.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(transformer.parameters(), lr=1e-4, betas=(0.9, 0.98), eps=1e-9)
trainer = BaseTrainer(model= transformer, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
trainer.fit(num_epochs=30)
# Out:
# Epoch 1/30
# 26/26 - train_loss: 1.9467 - train_accuracy: 19.6752%                 - val_loss: 0.7628 - val_accuracy: 26.2626%
# Epoch 2/30
# 26/26 - train_loss: 1.7307 - train_accuracy: 19.2380%                 - val_loss: 0.8241 - val_accuracy: 12.6263%
# Epoch 3/30
# 26/26 - train_loss: 1.6921 - train_accuracy: 21.7989%                 - val_loss: 0.7971 - val_accuracy: 27.2727%
# Epoch 4/30
# 26/26 - train_loss: 1.7076 - train_accuracy: 21.9863%                 - val_loss: 0.7763 - val_accuracy: 18.1818%
# Epoch 5/30
# 26/26 - train_loss: 1.7133 - train_accuracy: 21.7989%                 - val_loss: 0.7617 - val_accuracy: 18.1818%
# Epoch 6/30
# 26/26 - train_loss: 1.6991 - train_accuracy: 21.6740%                 - val_loss: 0.7745 - val_accuracy: 34.8485%
# Epoch 7/30
# 26/26 - train_loss: 1.2794 - train_accuracy: 42.7233%                 - val_loss: 0.2860 - val_accuracy: 67.1717%
# Epoch 8/30
# 26/26 - train_loss: 0.6355 - train_accuracy: 72.2049%                 - val_loss: 0.2011 - val_accuracy: 80.3030%
# Epoch 9/30
# 26/26 - train_loss: 0.3205 - train_accuracy: 87.7577%                 - val_loss: 0.0584 - val_accuracy: 90.9091%
# Epoch 10/30
# 26/26 - train_loss: 0.1730 - train_accuracy: 93.5665%                 - val_loss: 0.0251 - val_accuracy: 94.4444%
# Epoch 11/30
# 26/26 - train_loss: 0.1063 - train_accuracy: 95.1280%                 - val_loss: 0.0079 - val_accuracy: 93.4343%
# Epoch 12/30
# 26/26 - train_loss: 0.0876 - train_accuracy: 96.3773%                 - val_loss: 0.0062 - val_accuracy: 95.9596%
# Epoch 13/30
# 26/26 - train_loss: 0.0673 - train_accuracy: 97.0019%                 - val_loss: 0.0010 - val_accuracy: 94.4444%
# Epoch 14/30
# 26/26 - train_loss: 0.0446 - train_accuracy: 98.1262%                 - val_loss: 0.0002 - val_accuracy: 96.9697%
# Epoch 15/30
# 26/26 - train_loss: 0.0799 - train_accuracy: 97.5640%                 - val_loss: 0.0600 - val_accuracy: 83.8384%
# Epoch 16/30
# 26/26 - train_loss: 0.1539 - train_accuracy: 95.7527%                 - val_loss: 0.0342 - val_accuracy: 92.9293%
# Epoch 17/30
# 26/26 - train_loss: 0.0836 - train_accuracy: 97.7514%                 - val_loss: 0.0037 - val_accuracy: 96.4646%
# Epoch 18/30
# 26/26 - train_loss: 0.0482 - train_accuracy: 98.8132%                 - val_loss: 0.0046 - val_accuracy: 95.9596%
# Epoch 19/30
# 26/26 - train_loss: 0.0356 - train_accuracy: 98.9382%                 - val_loss: 0.0008 - val_accuracy: 94.9495%
# Epoch 20/30
# 26/26 - train_loss: 0.0131 - train_accuracy: 99.5628%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 21/30
# 26/26 - train_loss: 0.0202 - train_accuracy: 99.3129%                 - val_loss: 0.0002 - val_accuracy: 96.9697%
# Epoch 22/30
# 26/26 - train_loss: 0.0036 - train_accuracy: 99.8751%                 - val_loss: 0.0002 - val_accuracy: 96.9697%
# Epoch 23/30
# 26/26 - train_loss: 0.0008 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 24/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 25/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 26/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 27/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 28/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 29/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%

# %% [markdown]
# #### <font color="red">**Question 4.2**</font>
# **Prefix prompt-tuning with Transformers: You need to implement the prefix prompt-tuning with Transformers. Basically, we base on a pre-trained Transformer, add prefix prompts, and do fine-tuning for a target dataset.**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# To implement prefix prompt-tuning with pretrained Transformers, we first need to create the Bert dataset.

# %%
from transformers import AutoModel, AutoTokenizer
#from transformers import AutoModel, AutoTokenizer, AdamW
from datasets import Dataset

model_name = "bert-base-uncased"  # BERT or any similar model

# Tokenize input and prepare model inputs
tokenizer = AutoTokenizer.from_pretrained(model_name)

dataset = Dataset.from_dict({"text": dm.str_questions, "label": dm.numeral_labels})

# Tokenize the dataset
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length= 36)

dataset = dataset.map(tokenize_function, batched=True)
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
print(dataset)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 2000
# })

# %%
from torch.optim import AdamW

# %% [markdown]
# The following function splits the BERT dataset `dataset` into three BERT datasets for training, valid, and testing.

# %%
def train_valid_test_split(dataset, train_ratio=0.8, test_ratio = 0.1):
    num_sentences = len(dataset)
    train_size = int(num_sentences*train_ratio) +1
    test_size = int(num_sentences*test_ratio) +1
    valid_size = num_sentences - (train_size + test_size)
    train_set = dataset[:train_size]
    train_set = Dataset.from_dict(train_set)
    train_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    test_set = dataset[-test_size:]
    test_set = Dataset.from_dict(test_set)
    test_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    valid_set = dataset[train_size:-test_size]
    valid_set = Dataset.from_dict(valid_set)
    valid_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
    valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)
    return train_loader, test_loader, valid_loader

# %%
train_loader, test_loader, valid_loader = train_valid_test_split(dataset)

# %% [markdown]
# You need to implement the class `PrefixTuningForClassification` for the prefix prompt fine-tuning. We first load a pre-trained BERT model specified by `model_name`. The parameter `prefix_length` specifies the length of the prefix prompts we add to the pre-trained BERT model. Specifically, given the input batch `[batch_size, seq_len]`, we input to the embedding layer of the pre-trained BERT model to obtain `[batch_size, seq_len, embed_size]`. We create the prefix prompts $P$ of the size `[prefix_length, embed_size]` and concatenate to the embeddings from the pre-trained BERT to obtain `[batch_size, seq_len + prefix_length, embed_size]`. This concatenation tensor will then be fed to the encoder layers of the pre-trained BERT layer to obtain the last `[batch_size, seq_len + prefix_length, embed_size]`.

# %% [markdown]
# We then take mean across the seq_len to obtain `[batch_size, embed_size]` on which we can build up a linear layer for making predictions. Please note that **the parameters to tune include the prefix prompts $P$** and **the output linear layer**, and you should freeze the parameters of the BERT pre-trained model. Moreover, your code should cover the edge case when `prefix_length=None`. In this case, we do not insert any prefix prompts and we only do fine-tuning for the output linear layer on top.

# %%
class PrefixTuningForClassification(nn.Module):
    def __init__(self, model_name, prefix_length=None, data_manager = None):
        super(PrefixTuningForClassification, self).__init__()

        # Load the pretrained transformer model (BERT-like model)
        self.model = AutoModel.from_pretrained(model_name).to(device)
        self.hidden_size =  self.model.config.hidden_size
        self.prefix_length = prefix_length
        self.num_classes = data_manager.num_classes
        # Insert your code here
        for param in self.model.parameters():
            param.requires_grad = False

        #Create additional prefix embeddings that are trainable
        self.prefix_embeddings = nn.Parameter(torch.randn(prefix_length, self.hidden_size) * 0.02)

        #Drop out
        self.dropout = nn.Dropout(0.1)

        #Classifier Head
        self.classifier = nn.Linear(self.hidden_size, self.num_classes)


    def forward(self, input_ids, attention_mask):
        # Insert your code here
        batch_size = input_ids.shape[0]
        #Retrive Embeddings from pretrained BERT
        input_embeddings = self.model.embeddings(input_ids)
        # Expand prefix embeddings for the batch
        prefix_embeddings_expanded = self.prefix_embeddings.unsqueeze(0).expand(batch_size, -1, -1)
        # Concatenate prefix embeddings with input embeddings
        combined_embeddings = torch.cat([prefix_embeddings_expanded, input_embeddings], dim=1)

        # Create extended attention mask for prefix + input
        prefix_attention_mask = torch.ones(batch_size, self.prefix_length, dtype=attention_mask.dtype, device=attention_mask.device)

        #Concatenate prefix mask to attention mask
        extended_attention_mask = torch.cat([prefix_attention_mask, attention_mask], dim=1)

        outputs = self.model(inputs_embeds=combined_embeddings, attention_mask=extended_attention_mask, return_dict=True)

        last_hidden_state = outputs.last_hidden_state

        # Use [CLS] token representation (first token after prefix)
        cls_representation = last_hidden_state[:, self.prefix_length, :]

        # Apply dropout
        cls_representation = self.dropout(cls_representation)

        # Classification
        # Shape: [batch_size, num_classes]
        logits = self.classifier(cls_representation)

        return logits

# %% [markdown]
# You can use the following `FineTunedBaseTrainer` to train the prompt fine-tuning models.

# %%
class FineTunedBaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for batch in self.train_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)
            self.optimizer.zero_grad()
            outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for batch in loader:
                input_ids = batch["input_ids"].to(device)
                labels = batch["label"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# We declare and train the prefix-prompt tuning model. In addition, you need to be patient with this model because it might converge slowly with many epochs.

# %%
prefix_tuning_model = PrefixTuningForClassification(model_name = "bert-base-uncased", prefix_length = 5, data_manager = dm).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
if prefix_tuning_model.prefix_length is not None:
  optimizer = torch.optim.Adam(list(prefix_tuning_model.classifier.parameters()) + [prefix_tuning_model.prefix_embeddings], lr=5e-5)
else:
  optimizer = torch.optim.Adam(prefix_tuning_model.classifier.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()
trainer = FineTunedBaseTrainer(model= prefix_tuning_model, criterion=criterion, optimizer=optimizer, train_loader=train_loader, val_loader=valid_loader)
trainer.fit(num_epochs=100)
# Out:
# Epoch 1/100
# 26/26 - train_loss: 1.9141 - train_accuracy: 3.9975%                 - val_loss: 0.9666 - val_accuracy: 4.5455%
# Epoch 2/100
# 26/26 - train_loss: 1.8262 - train_accuracy: 13.8663%                 - val_loss: 0.9255 - val_accuracy: 22.2222%
# Epoch 3/100
# 26/26 - train_loss: 1.7532 - train_accuracy: 21.7989%                 - val_loss: 0.9009 - val_accuracy: 26.7677%
# Epoch 4/100
# 26/26 - train_loss: 1.7109 - train_accuracy: 26.4834%                 - val_loss: 0.8748 - val_accuracy: 24.7475%
# Epoch 5/100
# 26/26 - train_loss: 1.6860 - train_accuracy: 28.9819%                 - val_loss: 0.8576 - val_accuracy: 27.7778%
# Epoch 6/100
# 26/26 - train_loss: 1.6499 - train_accuracy: 30.0437%                 - val_loss: 0.8327 - val_accuracy: 31.3131%
# Epoch 7/100
# 26/26 - train_loss: 1.6239 - train_accuracy: 33.8538%                 - val_loss: 0.8176 - val_accuracy: 39.8990%
# Epoch 8/100
# 26/26 - train_loss: 1.5903 - train_accuracy: 33.4166%                 - val_loss: 0.8044 - val_accuracy: 42.9293%
# Epoch 9/100
# 26/26 - train_loss: 1.6259 - train_accuracy: 38.0387%                 - val_loss: 0.7874 - val_accuracy: 45.9596%
# Epoch 10/100
# 26/26 - train_loss: 1.5760 - train_accuracy: 37.1018%                 - val_loss: 0.7677 - val_accuracy: 46.9697%
# Epoch 11/100
# 26/26 - train_loss: 1.5714 - train_accuracy: 39.4129%                 - val_loss: 0.7441 - val_accuracy: 51.5152%
# Epoch 12/100
# 26/26 - train_loss: 1.5293 - train_accuracy: 43.8476%                 - val_loss: 0.7215 - val_accuracy: 53.5354%
# Epoch 13/100
# 26/26 - train_loss: 1.5205 - train_accuracy: 43.6602%                 - val_loss: 0.6893 - val_accuracy: 53.0303%
# Epoch 14/100
# 26/26 - train_loss: 1.4899 - train_accuracy: 45.9713%                 - val_loss: 0.6694 - val_accuracy: 56.0606%
# Epoch 15/100
# 26/26 - train_loss: 1.4691 - train_accuracy: 45.6590%                 - val_loss: 0.6371 - val_accuracy: 53.5354%
# Epoch 16/100
# 26/26 - train_loss: 1.4557 - train_accuracy: 48.0325%                 - val_loss: 0.6174 - val_accuracy: 55.0505%
# Epoch 17/100
# 26/26 - train_loss: 1.4036 - train_accuracy: 49.4066%                 - val_loss: 0.6087 - val_accuracy: 57.0707%
# Epoch 18/100
# 26/26 - train_loss: 1.4194 - train_accuracy: 49.0943%                 - val_loss: 0.5927 - val_accuracy: 59.5960%
# Epoch 19/100
# 26/26 - train_loss: 1.4023 - train_accuracy: 49.7814%                 - val_loss: 0.5838 - val_accuracy: 59.0909%
# Epoch 20/100
# 26/26 - train_loss: 1.3635 - train_accuracy: 51.3429%                 - val_loss: 0.5609 - val_accuracy: 63.1313%
# Epoch 21/100
# 26/26 - train_loss: 1.3555 - train_accuracy: 52.5297%                 - val_loss: 0.5329 - val_accuracy: 63.1313%
# Epoch 22/100
# 26/26 - train_loss: 1.4283 - train_accuracy: 54.9656%                 - val_loss: 0.5261 - val_accuracy: 66.1616%
# Epoch 23/100
# 26/26 - train_loss: 1.3226 - train_accuracy: 57.9013%                 - val_loss: 0.5123 - val_accuracy: 69.1919%
# Epoch 24/100
# 26/26 - train_loss: 1.3012 - train_accuracy: 61.0868%                 - val_loss: 0.4962 - val_accuracy: 71.2121%
# Epoch 25/100
# 26/26 - train_loss: 1.2956 - train_accuracy: 61.2742%                 - val_loss: 0.4916 - val_accuracy: 71.7172%
# Epoch 26/100
# 26/26 - train_loss: 1.2870 - train_accuracy: 62.9606%                 - val_loss: 0.4733 - val_accuracy: 72.7273%
# Epoch 27/100
# 26/26 - train_loss: 1.2694 - train_accuracy: 64.1474%                 - val_loss: 0.4523 - val_accuracy: 74.2424%
# Epoch 28/100
# 26/26 - train_loss: 1.2181 - train_accuracy: 66.0837%                 - val_loss: 0.4416 - val_accuracy: 72.7273%
# Epoch 29/100
# 26/26 - train_loss: 1.2175 - train_accuracy: 66.6458%                 - val_loss: 0.4327 - val_accuracy: 73.7374%
# Epoch 30/100
# 26/26 - train_loss: 1.1986 - train_accuracy: 64.7720%                 - val_loss: 0.4263 - val_accuracy: 77.7778%
# Epoch 31/100
# 26/26 - train_loss: 1.1711 - train_accuracy: 66.3960%                 - val_loss: 0.4216 - val_accuracy: 76.7677%
# Epoch 32/100
# 26/26 - train_loss: 1.1482 - train_accuracy: 68.7695%                 - val_loss: 0.4077 - val_accuracy: 74.2424%
# Epoch 33/100
# 26/26 - train_loss: 1.1296 - train_accuracy: 70.2061%                 - val_loss: 0.3949 - val_accuracy: 77.2727%
# Epoch 34/100
# 26/26 - train_loss: 1.2046 - train_accuracy: 69.0194%                 - val_loss: 0.3842 - val_accuracy: 78.2828%
# Epoch 35/100
# 26/26 - train_loss: 1.1404 - train_accuracy: 71.0181%                 - val_loss: 0.3865 - val_accuracy: 78.7879%
# Epoch 36/100
# 26/26 - train_loss: 1.0486 - train_accuracy: 72.1424%                 - val_loss: 0.3976 - val_accuracy: 78.2828%
# Epoch 37/100
# 26/26 - train_loss: 1.0495 - train_accuracy: 72.2049%                 - val_loss: 0.3790 - val_accuracy: 78.2828%
# Epoch 38/100
# 26/26 - train_loss: 1.0471 - train_accuracy: 72.2049%                 - val_loss: 0.3688 - val_accuracy: 78.2828%
# Epoch 39/100
# 26/26 - train_loss: 1.0272 - train_accuracy: 70.5184%                 - val_loss: 0.3644 - val_accuracy: 77.2727%
# Epoch 40/100
# 26/26 - train_loss: 1.0220 - train_accuracy: 73.1418%                 - val_loss: 0.3469 - val_accuracy: 78.2828%
# Epoch 41/100
# 26/26 - train_loss: 0.9791 - train_accuracy: 74.5159%                 - val_loss: 0.3430 - val_accuracy: 79.7980%
# Epoch 42/100
# 26/26 - train_loss: 0.9825 - train_accuracy: 74.2661%                 - val_loss: 0.3388 - val_accuracy: 79.7980%
# Epoch 43/100
# 26/26 - train_loss: 0.9596 - train_accuracy: 73.7664%                 - val_loss: 0.3384 - val_accuracy: 79.2929%
# Epoch 44/100
# 26/26 - train_loss: 0.9592 - train_accuracy: 75.0781%                 - val_loss: 0.3311 - val_accuracy: 80.8081%
# Epoch 45/100
# 26/26 - train_loss: 0.9218 - train_accuracy: 74.5159%                 - val_loss: 0.3208 - val_accuracy: 81.8182%
# Epoch 46/100
# 26/26 - train_loss: 0.9189 - train_accuracy: 75.3279%                 - val_loss: 0.3090 - val_accuracy: 81.8182%
# Epoch 47/100
# 26/26 - train_loss: 0.8900 - train_accuracy: 76.7645%                 - val_loss: 0.3148 - val_accuracy: 82.3232%
# Epoch 48/100
# 26/26 - train_loss: 0.8749 - train_accuracy: 75.9525%                 - val_loss: 0.3027 - val_accuracy: 82.3232%
# Epoch 49/100
# 26/26 - train_loss: 0.8648 - train_accuracy: 77.2017%                 - val_loss: 0.2817 - val_accuracy: 83.3333%
# Epoch 50/100
# 26/26 - train_loss: 0.8451 - train_accuracy: 78.3885%                 - val_loss: 0.2883 - val_accuracy: 84.3434%
# Epoch 51/100
# 26/26 - train_loss: 0.8464 - train_accuracy: 78.2011%                 - val_loss: 0.2900 - val_accuracy: 84.3434%
# Epoch 52/100
# 26/26 - train_loss: 0.8439 - train_accuracy: 79.6377%                 - val_loss: 0.2998 - val_accuracy: 85.3535%
# Epoch 53/100
# 26/26 - train_loss: 0.8222 - train_accuracy: 77.7639%                 - val_loss: 0.2590 - val_accuracy: 85.3535%
# Epoch 54/100
# 26/26 - train_loss: 0.8082 - train_accuracy: 79.4503%                 - val_loss: 0.2494 - val_accuracy: 84.8485%
# Epoch 55/100
# 26/26 - train_loss: 0.7861 - train_accuracy: 78.3260%                 - val_loss: 0.2575 - val_accuracy: 86.3636%
# Epoch 56/100
# 26/26 - train_loss: 0.7619 - train_accuracy: 79.7002%                 - val_loss: 0.2667 - val_accuracy: 87.3737%
# Epoch 57/100
# 26/26 - train_loss: 0.7603 - train_accuracy: 78.8257%                 - val_loss: 0.2587 - val_accuracy: 87.8788%
# Epoch 58/100
# 26/26 - train_loss: 0.7906 - train_accuracy: 80.3248%                 - val_loss: 0.2359 - val_accuracy: 86.3636%
# Epoch 59/100
# 26/26 - train_loss: 0.7649 - train_accuracy: 80.0125%                 - val_loss: 0.2393 - val_accuracy: 87.8788%
# Epoch 60/100
# 26/26 - train_loss: 0.7198 - train_accuracy: 81.0743%                 - val_loss: 0.2463 - val_accuracy: 89.8990%
# Epoch 61/100
# 26/26 - train_loss: 0.6871 - train_accuracy: 82.0112%                 - val_loss: 0.2141 - val_accuracy: 86.8687%
# Epoch 62/100
# 26/26 - train_loss: 0.7019 - train_accuracy: 80.3873%                 - val_loss: 0.1992 - val_accuracy: 86.3636%
# Epoch 63/100
# 26/26 - train_loss: 0.6907 - train_accuracy: 79.3879%                 - val_loss: 0.2015 - val_accuracy: 88.3838%
# Epoch 64/100
# 26/26 - train_loss: 0.7141 - train_accuracy: 81.9488%                 - val_loss: 0.1991 - val_accuracy: 88.8889%
# Epoch 65/100
# 26/26 - train_loss: 0.6931 - train_accuracy: 80.6371%                 - val_loss: 0.1897 - val_accuracy: 87.8788%
# Epoch 66/100
# 26/26 - train_loss: 0.6653 - train_accuracy: 81.9488%                 - val_loss: 0.2063 - val_accuracy: 88.8889%
# Epoch 67/100
# 26/26 - train_loss: 0.6558 - train_accuracy: 83.1355%                 - val_loss: 0.1998 - val_accuracy: 88.8889%
# Epoch 68/100
# 26/26 - train_loss: 0.7300 - train_accuracy: 82.8857%                 - val_loss: 0.1812 - val_accuracy: 87.8788%
# Epoch 69/100
# 26/26 - train_loss: 0.6479 - train_accuracy: 81.6989%                 - val_loss: 0.1620 - val_accuracy: 88.3838%
# Epoch 70/100
# 26/26 - train_loss: 0.6751 - train_accuracy: 82.3235%                 - val_loss: 0.1744 - val_accuracy: 88.8889%
# Epoch 71/100
# 26/26 - train_loss: 0.6370 - train_accuracy: 82.7608%                 - val_loss: 0.1616 - val_accuracy: 89.8990%
# Epoch 72/100
# 26/26 - train_loss: 0.6072 - train_accuracy: 84.0100%                 - val_loss: 0.1701 - val_accuracy: 88.8889%
# Epoch 73/100
# 26/26 - train_loss: 0.6441 - train_accuracy: 84.0725%                 - val_loss: 0.1667 - val_accuracy: 89.3939%
# Epoch 74/100
# 26/26 - train_loss: 0.5754 - train_accuracy: 84.8220%                 - val_loss: 0.1540 - val_accuracy: 88.3838%
# Epoch 75/100
# 26/26 - train_loss: 0.5916 - train_accuracy: 84.8220%                 - val_loss: 0.1578 - val_accuracy: 89.3939%
# Epoch 76/100
# 26/26 - train_loss: 0.5982 - train_accuracy: 84.6346%                 - val_loss: 0.1560 - val_accuracy: 89.3939%
# Epoch 77/100
# 26/26 - train_loss: 0.5692 - train_accuracy: 84.4472%                 - val_loss: 0.1469 - val_accuracy: 89.8990%
# Epoch 78/100
# 26/26 - train_loss: 0.5541 - train_accuracy: 85.1343%                 - val_loss: 0.1528 - val_accuracy: 89.8990%
# Epoch 79/100
# 26/26 - train_loss: 0.5582 - train_accuracy: 83.7601%                 - val_loss: 0.1512 - val_accuracy: 89.8990%
# Epoch 80/100
# 26/26 - train_loss: 0.5453 - train_accuracy: 85.5091%                 - val_loss: 0.1442 - val_accuracy: 89.8990%
# Epoch 81/100
# 26/26 - train_loss: 0.5322 - train_accuracy: 85.8838%                 - val_loss: 0.1438 - val_accuracy: 89.8990%
# Epoch 82/100
# 26/26 - train_loss: 0.5322 - train_accuracy: 86.0712%                 - val_loss: 0.1393 - val_accuracy: 89.8990%
# Epoch 83/100

# %% [markdown]
# #### <font color="red">**Question 4.3**</font>
# **For any models defined in the previous questions (of all parts), you are free to fine-tune hyperparameters, e.g., `optimizer`, `learning_rate`, `state_sizes`, such that you get a best model, i.e., the one with the highest accuracy on the test set. You will need to report (i) what is your best model,  (ii) its accuracy on the test set, and (iii) the values of its hyperparameters. Note that you must report your best model's accuracy with rounding to 4 decimal places, i.e., 0.xxxx. You will also need to upload your best model (or provide us with the link to download your best model). The assessment will be based on your best model's accuracy, with up to 10 marks available, specifically:**
# * The best accuracy $\ge$ 0.97: 10 marks
# * 0.97 $>$ The best accuracy $\ge$ 0.92: 7 marks
# * 0.92 $>$ The best accuracy $\ge$ 0.85: 4 marks
# * The best accuracy $<$ 0.85: 0 mark
#
# **For this question, you can put below the code to train the best model. In this case, you need to show your code and the evidence of running regarding the best model. Moreover, if you save the best model, you need to provide the link to download the best model, the code to load the best model, and then evaluate on the test set.**
# <div style="text-align: right"><font color="red">[10 marks]</font></div>

# %%
import torch
import torch.nn as nn
from torch.optim import AdamW, Adam, SGD
import os
# Create checkpoint directory
checkpoint_dir = 'best model scores'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    print(f"Created checkpoint directory: {checkpoint_dir}")

prefix_lengths = [10, 15, 20]
learning_rates = [0.01, 0.05]
optimizers = ['AdamW', 'Adam']
weight_decays = [0.01, 0.03]
dropouts = [0.1, 0.3]

#track and record best model
best_val_accuracy = 0.0
best_test_accuracy = 0.0
best_config = None
best_model_state = None
best_checkpoint_path = None
results = []

for prefix_length in prefix_lengths:
    for lr in learning_rates:
        for optim in optimizers:
            for wd in weight_decays:
                for dropout in dropouts:
                    print("-" *30)
                    print(f"Prefix Length: {prefix_length}")
                    print(f"Learning Rate: {lr}")
                    print(f"Optimizer: {optim}")
                    print(f"Weight Decay: {wd}")
                    print(f"Dropout: {dropout}")

                    # Initialize model
                    prefix_best_model = PrefixTuningForClassification(model_name="bert-base-uncased", prefix_length=prefix_length, data_manager=dm).to(device)

                    # Update dropout
                    prefix_best_model.dropout = nn.Dropout(dropout)

                    # Setup optimizer
                    trainable_params = (list(prefix_best_model.classifier.parameters()) + [prefix_best_model.prefix_embeddings])

                    if optim == 'AdamW':
                        optimizer = AdamW(
                            trainable_params,
                            lr=lr,
                            weight_decay=wd
                        )
                    elif optim == 'Adam':
                        optimizer = Adam(
                            trainable_params,
                            lr=lr,
                            weight_decay=wd
                        )

                    # Setup loss
                    criterion = nn.CrossEntropyLoss()

                    # Create trainer
                    trainer = FineTunedBaseTrainer(model=prefix_best_model, criterion=criterion, optimizer=optimizer,
                                                   train_loader=train_loader, val_loader=valid_loader)

                    # Training
                    print("Training...")
                    trainer.fit(num_epochs=100)

                    # Evaluate
                    val_loss, val_accuracy = trainer.validate_one_epoch()
                    test_loss, test_accuracy = trainer.evaluate(test_loader)

                    # Store results
                    config = {
                        'prefix_length': prefix_length,
                        'learning_rate': lr,
                        'optimizer': optim,
                        'weight_decay': wd,
                        'dropout': dropout
                    }

                    result = {
                        'config': config,
                        'val_accuracy': val_accuracy,
                        'test_accuracy': test_accuracy,
                        'val_loss': val_loss,
                        'test_loss': test_loss
                    }
                    results.append(result)

                    # Print results
                    print()
                    print(f"Results:")
                    print(f"Val Accuracy: {val_accuracy:.4f}")
                    print(f"Test Accuracy: {test_accuracy:.4f}")

                    # Save checkpoint if validation accuracy has increased results
                    if test_accuracy > best_test_accuracy:
                        best_test_accuracy = test_accuracy
                        best_config = config.copy()
                        best_model_state = prefix_best_model.state_dict()

                        # Save checkpoint
                        checkpoint_path = os.path.join(
                            checkpoint_dir,
                            f'checkpoint_testacc{test_accuracy:.4f}.pth'
                        )

                        torch.save({
                            'model_state_dict': prefix_best_model.state_dict(),
                            'config': config,
                            'val_accuracy': val_accuracy,
                            'test_accuracy': test_accuracy,
                            'val_loss': val_loss,
                            'test_loss': test_loss,
                            'num_classes': dm.num_classes
                        }, checkpoint_path)

                        best_checkpoint_path = checkpoint_path

                        print(f"NEW BEST MODEL FOUND")



print("BEST MODEL")

print(f"Prefix Length: {best_config['prefix_length']}")
print(f"Learning Rate: {best_config['learning_rate']}")
print(f"Optimizer: {best_config['optimizer']}")
print(f"Weight Decay: {best_config['weight_decay']}")
print(f"Dropout: {best_config['dropout']}")
print(f"Test Accuracy: {best_test_accuracy:.4f}")

print(f"Best checkpoint saved at: {best_checkpoint_path}")

results_sorted = sorted(results, key=lambda x: x['test_accuracy'], reverse=True)
# save final best models
final_model_path = 'best_prefix_tuning_model.pth'

torch.save({
    'model_state_dict': best_model_state,
    'config': best_config,
    'test_accuracy': best_test_accuracy,
    'val_accuracy': best_val_accuracy,
    'num_classes': dm.num_classes,
    'all_results': results_sorted,
    'checkpoint_path': best_checkpoint_path
}, final_model_path)

print(f"Final best model saved as: {final_model_path}")
# Out:
# Created checkpoint directory: best model scores
# ------------------------------
# Prefix Length: 10
# Learning Rate: 0.01
# Optimizer: AdamW
# Weight Decay: 0.01
# Dropout: 0.1
# Training...
# Epoch 1/100
# 26/26 - train_loss: 1.0680 - train_accuracy: 59.6502%                 - val_loss: 0.0512 - val_accuracy: 92.4242%
# Epoch 2/100
# 26/26 - train_loss: 0.2987 - train_accuracy: 90.8182%                 - val_loss: 0.0006 - val_accuracy: 96.4646%
# Epoch 3/100
# 26/26 - train_loss: 0.1700 - train_accuracy: 93.8788%                 - val_loss: 0.0035 - val_accuracy: 97.4747%
# Epoch 4/100
# 26/26 - train_loss: 0.1179 - train_accuracy: 96.0025%                 - val_loss: 0.0002 - val_accuracy: 99.4949%
# Epoch 5/100
# 26/26 - train_loss: 0.0818 - train_accuracy: 97.3766%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 6/100
# 26/26 - train_loss: 0.0600 - train_accuracy: 98.3760%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 7/100
# 26/26 - train_loss: 0.0611 - train_accuracy: 98.0637%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 8/100
# 26/26 - train_loss: 0.0613 - train_accuracy: 98.1886%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 9/100
# 26/26 - train_loss: 0.0661 - train_accuracy: 97.9388%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 10/100
# 26/26 - train_loss: 0.0390 - train_accuracy: 98.8132%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 11/100
# 26/26 - train_loss: 0.0309 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 12/100
# 26/26 - train_loss: 0.0235 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 13/100
# 26/26 - train_loss: 0.0375 - train_accuracy: 98.7508%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 14/100
# 26/26 - train_loss: 0.0283 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 15/100
# 26/26 - train_loss: 0.0251 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 16/100
# 26/26 - train_loss: 0.0333 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 17/100
# 26/26 - train_loss: 0.0329 - train_accuracy: 98.6883%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 18/100
# 26/26 - train_loss: 0.0171 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 19/100
# 26/26 - train_loss: 0.0351 - train_accuracy: 98.6259%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 20/100
# 26/26 - train_loss: 0.0224 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 21/100
# 26/26 - train_loss: 0.0293 - train_accuracy: 98.9382%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 22/100
# 26/26 - train_loss: 0.0279 - train_accuracy: 98.8757%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 23/100
# 26/26 - train_loss: 0.0215 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 24/100
# 26/26 - train_loss: 0.0242 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 25/100
# 26/26 - train_loss: 0.0227 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 26/100
# 26/26 - train_loss: 0.0168 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 27/100
# 26/26 - train_loss: 0.0209 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 28/100
# 26/26 - train_loss: 0.0168 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 29/100
# 26/26 - train_loss: 0.0277 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 30/100
# 26/26 - train_loss: 0.0315 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 31/100
# 26/26 - train_loss: 0.0167 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 32/100
# 26/26 - train_loss: 0.0203 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 33/100
# 26/26 - train_loss: 0.0189 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 34/100
# 26/26 - train_loss: 0.0129 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 35/100
# 26/26 - train_loss: 0.0224 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 36/100
# 26/26 - train_loss: 0.0147 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 37/100
# 26/26 - train_loss: 0.0213 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 38/100
# 26/26 - train_loss: 0.0411 - train_accuracy: 98.6883%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 39/100
# 26/26 - train_loss: 0.0181 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 40/100
# 26/26 - train_loss: 0.0160 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 41/100
# 26/26 - train_loss: 0.0082 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 42/100
# 26/26 - train_loss: 0.0165 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 43/100
# 26/26 - train_loss: 0.0091 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 44/100
# 26/26 - train_loss: 0.0116 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 45/100
# 26/26 - train_loss: 0.0148 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 46/100
# 26/26 - train_loss: 0.0074 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 47/100
# 26/26 - train_loss: 0.0074 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 48/100
# 26/26 - train_loss: 0.0160 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 49/100
# 26/26 - train_loss: 0.0142 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 50/100
# 26/26 - train_loss: 0.0119 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 51/100
# 26/26 - train_loss: 0.0101 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 52/100
# 26/26 - train_loss: 0.0557 - train_accuracy: 98.1262%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 53/100
# 26/26 - train_loss: 0.0182 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 54/100
# 26/26 - train_loss: 0.0116 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 55/100
# 26/26 - train_loss: 0.0105 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 56/100
# 26/26 - train_loss: 0.0108 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 57/100
# 26/26 - train_loss: 0.0096 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 58/100
# 26/26 - train_loss: 0.0097 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 59/100
# 26/26 - train_loss: 0.0042 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 60/100
# 26/26 - train_loss: 0.0124 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 61/100
# 26/26 - train_loss: 0.0187 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 62/100
# 26/26 - train_loss: 0.0182 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 63/100
# 26/26 - train_loss: 0.0104 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 64/100
# 26/26 - train_loss: 0.0285 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 65/100
# 26/26 - train_loss: 0.0221 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 66/100
# 26/26 - train_loss: 0.0109 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 67/100
# 26/26 - train_loss: 0.0069 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 68/100
# 26/26 - train_loss: 0.0085 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 69/100
# 26/26 - train_loss: 0.0119 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 70/100
# 26/26 - train_loss: 0.0112 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 71/100
# 26/26 - train_loss: 0.0106 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 72/100
# 26/26 - train_loss: 0.0099 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 73/100
# 26/26 - train_loss: 0.0108 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 74/100
# 26/26 - train_loss: 0.0165 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 75/100
# 26/26 - train_loss: 0.0149 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 76/100
# 26/26 - train_loss: 0.0187 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 77/100
# 26/26 - train_loss: 0.0085 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 78/100
# 26/26 - train_loss: 0.0111 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 79/100
# 26/26 - train_loss: 0.0105 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 80/100
# 26/26 - train_loss: 0.0049 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 81/100
# 26/26 - train_loss: 0.0140 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 82/100
# 26/26 - train_loss: 0.0056 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 83/100
# 26/26 - train_loss: 0.0088 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 84/100
# 26/26 - train_loss: 0.0046 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 85/100
# 26/26 - train_loss: 0.0064 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 86/100
# 26/26 - train_loss: 0.0102 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 87/100
# 26/26 - train_loss: 0.0060 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 88/100
# 26/26 - train_loss: 0.0051 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 89/100
# 26/26 - train_loss: 0.0097 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 90/100
# 26/26 - train_loss: 0.0097 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 91/100
# 26/26 - train_loss: 0.0069 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 92/100
# 26/26 - train_loss: 0.0077 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 93/100
# 26/26 - train_loss: 0.0089 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 94/100
# 26/26 - train_loss: 0.0057 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 95/100
# 26/26 - train_loss: 0.0026 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 96/100
# 26/26 - train_loss: 0.0059 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 97/100
# 26/26 - train_loss: 0.0070 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 98/100
# 26/26 - train_loss: 0.0045 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 99/100
# 26/26 - train_loss: 0.0050 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 100/100
# 26/26 - train_loss: 0.0054 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
#
# Results:
# Val Accuracy: 0.9848
# Test Accuracy: 0.9900
# NEW BEST MODEL FOUND
# ------------------------------
# Prefix Length: 10
# Learning Rate: 0.01
# Optimizer: AdamW
# Weight Decay: 0.01
# Dropout: 0.3
# Training...
# Epoch 1/100
# 26/26 - train_loss: 1.2539 - train_accuracy: 53.1543%                 - val_loss: 0.1869 - val_accuracy: 86.3636%
# Epoch 2/100
# 26/26 - train_loss: 0.4113 - train_accuracy: 85.4466%                 - val_loss: 0.0272 - val_accuracy: 95.4545%
# Epoch 3/100
# 26/26 - train_loss: 0.2083 - train_accuracy: 93.3167%                 - val_loss: 0.0073 - val_accuracy: 96.4646%
# Epoch 4/100
# 26/26 - train_loss: 0.1800 - train_accuracy: 94.2536%                 - val_loss: 0.0052 - val_accuracy: 95.9596%
# Epoch 5/100
# 26/26 - train_loss: 0.1471 - train_accuracy: 95.1280%                 - val_loss: 0.0006 - val_accuracy: 96.4646%
# Epoch 6/100
# 26/26 - train_loss: 0.1077 - train_accuracy: 96.4397%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 7/100
# 26/26 - train_loss: 0.0944 - train_accuracy: 96.5022%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 8/100
# 26/26 - train_loss: 0.0826 - train_accuracy: 97.3142%                 - val_loss: 0.0001 - val_accuracy: 97.4747%
# Epoch 9/100
# 26/26 - train_loss: 0.0628 - train_accuracy: 97.6889%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 10/100
# 26/26 - train_loss: 0.0773 - train_accuracy: 97.6889%                 - val_loss: 0.0001 - val_accuracy: 97.9798%
# Epoch 11/100
# 26/26 - train_loss: 0.0505 - train_accuracy: 98.2511%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 12/100
# 26/26 - train_loss: 0.0533 - train_accuracy: 98.3760%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 13/100
# 26/26 - train_loss: 0.0445 - train_accuracy: 98.4385%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 14/100
# 26/26 - train_loss: 0.0541 - train_accuracy: 98.1262%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 15/100
# 26/26 - train_loss: 0.0669 - train_accuracy: 97.7514%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 16/100
# 26/26 - train_loss: 0.0455 - train_accuracy: 98.7508%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 17/100
# 26/26 - train_loss: 0.0298 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 18/100
# 26/26 - train_loss: 0.0274 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 19/100
# 26/26 - train_loss: 0.0274 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 20/100
# 26/26 - train_loss: 0.0261 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 21/100
# 26/26 - train_loss: 0.0299 - train_accuracy: 98.8757%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 22/100
# 26/26 - train_loss: 0.0381 - train_accuracy: 98.8132%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 23/100
# 26/26 - train_loss: 0.0299 - train_accuracy: 98.9382%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 24/100
# 26/26 - train_loss: 0.0249 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 25/100
# 26/26 - train_loss: 0.0292 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 26/100
# 26/26 - train_loss: 0.0295 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 27/100
# 26/26 - train_loss: 0.0185 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 28/100
# 26/26 - train_loss: 0.0275 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 29/100
# 26/26 - train_loss: 0.0234 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 30/100
# 26/26 - train_loss: 0.0201 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 31/100
# 26/26 - train_loss: 0.0166 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 32/100
# 26/26 - train_loss: 0.0276 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 33/100
# 26/26 - train_loss: 0.0296 - train_accuracy: 98.7508%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 34/100
# 26/26 - train_loss: 0.0236 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 35/100
# 26/26 - train_loss: 0.0155 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 36/100
# 26/26 - train_loss: 0.0119 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 37/100
# 26/26 - train_loss: 0.0289 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 38/100
# 26/26 - train_loss: 0.0213 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 39/100
# 26/26 - train_loss: 0.0459 - train_accuracy: 98.1886%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 40/100
# 26/26 - train_loss: 0.0318 - train_accuracy: 98.8132%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 41/100
# 26/26 - train_loss: 0.0213 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 42/100
# 26/26 - train_loss: 0.0213 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 43/100
# 26/26 - train_loss: 0.0221 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 44/100
# 26/26 - train_loss: 0.0147 - train_accuracy: 99.6877%                 - val_loss: 0.0094 - val_accuracy: 96.9697%
# Epoch 45/100
# 26/26 - train_loss: 0.0206 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 46/100
# 26/26 - train_loss: 0.0325 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 47/100
# 26/26 - train_loss: 0.0282 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 48/100
# 26/26 - train_loss: 0.0170 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 49/100
# 26/26 - train_loss: 0.0201 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 50/100
# 26/26 - train_loss: 0.0198 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 51/100
# 26/26 - train_loss: 0.0138 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 52/100
# 26/26 - train_loss: 0.0204 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 53/100
# 26/26 - train_loss: 0.0152 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 54/100
# 26/26 - train_loss: 0.0194 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 55/100
# 26/26 - train_loss: 0.0147 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 56/100
# 26/26 - train_loss: 0.0134 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 57/100
# 26/26 - train_loss: 0.0099 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 58/100
# 26/26 - train_loss: 0.0114 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 59/100
# 26/26 - train_loss: 0.0213 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 60/100
# 26/26 - train_loss: 0.0220 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 61/100
# 26/26 - train_loss: 0.0173 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 62/100
# 26/26 - train_loss: 0.0233 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 63/100
# 26/26 - train_loss: 0.0118 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 64/100
# 26/26 - train_loss: 0.0099 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 65/100
# 26/26 - train_loss: 0.0042 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 66/100
# 26/26 - train_loss: 0.0100 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 67/100
# 26/26 - train_loss: 0.0159 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 68/100
# 26/26 - train_loss: 0.0137 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 69/100
# 26/26 - train_loss: 0.0077 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 70/100
# 26/26 - train_loss: 0.0138 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 71/100
# 26/26 - train_loss: 0.0114 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 72/100
# 26/26 - train_loss: 0.0205 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 73/100
# 26/26 - train_loss: 0.0148 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 74/100
# 26/26 - train_loss: 0.0180 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 75/100
# 26/26 - train_loss: 0.0040 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 76/100
# 26/26 - train_loss: 0.0114 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 77/100
# 26/26 - train_loss: 0.0205 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 78/100
# 26/26 - train_loss: 0.0130 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 79/100
# 26/26 - train_loss: 0.0098 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 80/100
# 26/26 - train_loss: 0.0156 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 81/100
# 26/26 - train_loss: 0.0257 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 82/100
# 26/26 - train_loss: 0.0252 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 83/100
# 26/26 - train_loss: 0.0271 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 84/100
# 26/26 - train_loss: 0.0120 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 85/100
# 26/26 - train_loss: 0.0166 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 86/100
# 26/26 - train_loss: 0.0152 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 87/100
# 26/26 - train_loss: 0.0224 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 88/100
# 26/26 - train_loss: 0.0163 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 89/100
# 26/26 - train_loss: 0.0129 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 90/100
# 26/26 - train_loss: 0.0231 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 91/100
# 26/26 - train_loss: 0.0225 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 92/100
# 26/26 - train_loss: 0.0139 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 93/100
# 26/26 - train_loss: 0.0170 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 94/100
# 26/26 - train_loss: 0.0095 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 95/100
# 26/26 - train_loss: 0.0090 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 96/100
# 26/26 - train_loss: 0.0168 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 97/100
# 26/26 - train_loss: 0.0080 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 98/100
# 26/26 - train_loss: 0.0044 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 99/100
# 26/26 - train_loss: 0.0109 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 100/100
# 26/26 - train_loss: 0.0232 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
#
# Results:
# Val Accuracy: 0.9798
# Test Accuracy: 1.0000
# NEW BEST MODEL FOUND
# ------------------------------
# Prefix Length: 10
# Learning Rate: 0.01
# Optimizer: AdamW
# Weight Decay: 0.03
# Dropout: 0.1
# Training...
# Epoch 1/100
# 26/26 - train_loss: 1.2459 - train_accuracy: 52.6546%                 - val_loss: 0.3229 - val_accuracy: 84.3434%
# Epoch 2/100
# 26/26 - train_loss: 0.4704 - train_accuracy: 82.7608%                 - val_loss: 0.0364 - val_accuracy: 93.9394%
# Epoch 3/100
# 26/26 - train_loss: 0.2416 - train_accuracy: 91.9425%                 - val_loss: 0.0021 - val_accuracy: 98.4848%
# Epoch 4/100
# 26/26 - train_loss: 0.1409 - train_accuracy: 95.5653%                 - val_loss: 0.0009 - val_accuracy: 98.9899%
# Epoch 5/100
# 26/26 - train_loss: 0.0934 - train_accuracy: 97.0643%                 - val_loss: 0.0025 - val_accuracy: 98.9899%
# Epoch 6/100
# 26/26 - train_loss: 0.0886 - train_accuracy: 97.3766%                 - val_loss: 0.0015 - val_accuracy: 97.9798%
# Epoch 7/100
# 26/26 - train_loss: 0.0727 - train_accuracy: 97.5640%                 - val_loss: 0.0003 - val_accuracy: 99.4949%
# Epoch 8/100
# 26/26 - train_loss: 0.0842 - train_accuracy: 97.5016%                 - val_loss: 0.0017 - val_accuracy: 97.9798%
# Epoch 9/100
# 26/26 - train_loss: 0.1263 - train_accuracy: 95.7527%                 - val_loss: 0.0003 - val_accuracy: 99.4949%
# Epoch 10/100
# 26/26 - train_loss: 0.0669 - train_accuracy: 97.6265%                 - val_loss: 0.0018 - val_accuracy: 96.9697%
# Epoch 11/100
# 26/26 - train_loss: 0.0823 - train_accuracy: 97.0019%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 12/100
# 26/26 - train_loss: 0.0570 - train_accuracy: 97.7514%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 13/100
# 26/26 - train_loss: 0.0488 - train_accuracy: 98.1262%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 14/100
# 26/26 - train_loss: 0.0429 - train_accuracy: 98.3760%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 15/100
# 26/26 - train_loss: 0.0378 - train_accuracy: 98.6259%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 16/100
# 26/26 - train_loss: 0.0299 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 17/100
# 26/26 - train_loss: 0.0343 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 18/100
# 26/26 - train_loss: 0.0380 - train_accuracy: 98.6259%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 19/100
# 26/26 - train_loss: 0.0251 - train_accuracy: 99.3129%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 20/100
# 26/26 - train_loss: 0.0272 - train_accuracy: 99.0006%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 21/100
# 26/26 - train_loss: 0.0227 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 22/100
# 26/26 - train_loss: 0.0212 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 23/100
# 26/26 - train_loss: 0.0236 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 24/100
# 26/26 - train_loss: 0.0246 - train_accuracy: 99.1880%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 25/100
# 26/26 - train_loss: 0.0166 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 26/100
# 26/26 - train_loss: 0.0211 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 27/100
# 26/26 - train_loss: 0.0246 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 28/100
# 26/26 - train_loss: 0.0781 - train_accuracy: 97.2517%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 29/100
# 26/26 - train_loss: 0.0446 - train_accuracy: 98.6883%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 30/100
# 26/26 - train_loss: 0.0272 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 31/100
# 26/26 - train_loss: 0.0261 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 32/100
# 26/26 - train_loss: 0.0235 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 33/100
# 26/26 - train_loss: 0.0316 - train_accuracy: 98.7508%                 - val_loss: 0.0000 - val_accuracy: 100.0000%
# Epoch 34/100
# 26/26 - train_loss: 0.0257 - train_accuracy: 99.1880%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 35/100
# 26/26 - train_loss: 0.0149 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 36/100
# 26/26 - train_loss: 0.0217 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 37/100
# 26/26 - train_loss: 0.0343 - train_accuracy: 98.7508%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 38/100
# 26/26 - train_loss: 0.0317 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 39/100
# 26/26 - train_loss: 0.0405 - train_accuracy: 98.6259%                 - val_loss: 0.0003 - val_accuracy: 97.9798%
# Epoch 40/100
# 26/26 - train_loss: 0.0335 - train_accuracy: 98.8757%                 - val_loss: 0.0002 - val_accuracy: 99.4949%
# Epoch 41/100
# 26/26 - train_loss: 0.0279 - train_accuracy: 98.8132%                 - val_loss: 0.0001 - val_accuracy: 99.4949%
# Epoch 42/100
# 26/26 - train_loss: 0.0196 - train_accuracy: 99.2505%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 43/100
# 26/26 - train_loss: 0.0227 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 44/100
# 26/26 - train_loss: 0.0291 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 45/100
# 26/26 - train_loss: 0.0134 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 46/100
# 26/26 - train_loss: 0.0202 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 47/100
# 26/26 - train_loss: 0.0131 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 48/100
# 26/26 - train_loss: 0.0122 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 49/100
# 26/26 - train_loss: 0.0085 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 50/100
# 26/26 - train_loss: 0.0100 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 51/100
# 26/26 - train_loss: 0.0091 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 52/100
# 26/26 - train_loss: 0.0113 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 53/100
# 26/26 - train_loss: 0.0163 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 54/100
# 26/26 - train_loss: 0.0128 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 55/100
# 26/26 - train_loss: 0.0217 - train_accuracy: 99.3754%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 56/100
# 26/26 - train_loss: 0.0227 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 57/100
# 26/26 - train_loss: 0.0122 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 58/100
# 26/26 - train_loss: 0.0106 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 59/100
# 26/26 - train_loss: 0.0162 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 60/100
# 26/26 - train_loss: 0.0088 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 61/100
# 26/26 - train_loss: 0.0098 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 62/100
# 26/26 - train_loss: 0.0133 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 63/100
# 26/26 - train_loss: 0.0130 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 64/100
# 26/26 - train_loss: 0.0119 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 65/100
# 26/26 - train_loss: 0.0231 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 66/100
# 26/26 - train_loss: 0.1305 - train_accuracy: 96.1899%                 - val_loss: 0.0003 - val_accuracy: 97.9798%
# Epoch 67/100
# 26/26 - train_loss: 0.0566 - train_accuracy: 98.3760%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 68/100
# 26/26 - train_loss: 0.0812 - train_accuracy: 97.2517%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 69/100
# 26/26 - train_loss: 0.0270 - train_accuracy: 98.6883%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 70/100
# 26/26 - train_loss: 0.0299 - train_accuracy: 98.9382%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 71/100
# 26/26 - train_loss: 0.0148 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 72/100
# 26/26 - train_loss: 0.0179 - train_accuracy: 99.1255%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 73/100
# 26/26 - train_loss: 0.0179 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 74/100
# 26/26 - train_loss: 0.0202 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 75/100
# 26/26 - train_loss: 0.0136 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 76/100
# 26/26 - train_loss: 0.0235 - train_accuracy: 99.0631%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 77/100
# 26/26 - train_loss: 0.0062 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 78/100
# 26/26 - train_loss: 0.0115 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 79/100
# 26/26 - train_loss: 0.0108 - train_accuracy: 99.4379%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 80/100
# 26/26 - train_loss: 0.0090 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 81/100
# 26/26 - train_loss: 0.0056 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 82/100
# 26/26 - train_loss: 0.0109 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 83/100
# 26/26 - train_loss: 0.0056 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 84/100
# 26/26 - train_loss: 0.0158 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 85/100
# 26/26 - train_loss: 0.0085 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 86/100
# 26/26 - train_loss: 0.0084 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 87/100
# 26/26 - train_loss: 0.0078 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 88/100
# 26/26 - train_loss: 0.0047 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 89/100
# 26/26 - train_loss: 0.0076 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 90/100
# 26/26 - train_loss: 0.0064 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 91/100
# 26/26 - train_loss: 0.0078 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 92/100
# 26/26 - train_loss: 0.0105 - train_accuracy: 99.6252%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 93/100
# 26/26 - train_loss: 0.0070 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 94/100
# 26/26 - train_loss: 0.0138 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 95/100
# 26/26 - train_loss: 0.0099 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 96/100
# 26/26 - train_loss: 0.0079 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 97/100
# 26/26 - train_loss: 0.0057 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 98/100
# 26/26 - train_loss: 0.0044 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 99/100
# 26/26 - train_loss: 0.0052 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 99.4949%
# Epoch 100/100
# 26/26 - train_loss: 0.0122 - train_accuracy: 99.5628%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
#
# Results:
# Val Accuracy: 0.9899
# Test Accuracy: 0.9950
# ------------------------------
# Prefix Length: 10
# Learning Rate: 0.01
# Optimizer: AdamW
# Weight Decay: 0.03
# Dropout: 0.3
# Training...
# Epoch 1/100
# 26/26 - train_loss: 1.3149 - train_accuracy: 49.3442%                 - val_loss: 0.3838 - val_accuracy: 72.7273%
# Epoch 2/100
# 26/26 - train_loss: 0.5980 - train_accuracy: 78.7008%                 - val_loss: 0.0790 - val_accuracy: 91.4141%
# Epoch 3/100
# 26/26 - train_loss: 0.3413 - train_accuracy: 88.6946%                 - val_loss: 0.0658 - val_accuracy: 94.4444%
# Epoch 4/100
# 26/26 - train_loss: 0.1937 - train_accuracy: 94.4410%                 - val_loss: 0.0016 - val_accuracy: 95.9596%
# Epoch 5/100
# 26/26 - train_loss: 0.1603 - train_accuracy: 94.1911%                 - val_loss: 0.0008 - val_accuracy: 97.9798%
# Epoch 6/100
# 26/26 - train_loss: 0.1138 - train_accuracy: 96.5022%                 - val_loss: 0.0003 - val_accuracy: 97.4747%
# Epoch 7/100
# 26/26 - train_loss: 0.1004 - train_accuracy: 96.9394%                 - val_loss: 0.0004 - val_accuracy: 97.4747%
# Epoch 8/100
# 26/26 - train_loss: 0.1224 - train_accuracy: 96.1274%                 - val_loss: 0.0002 - val_accuracy: 97.4747%
# Epoch 9/100
# 26/26 - train_loss: 0.0867 - train_accuracy: 96.6271%                 - val_loss: 0.0001 - val_accuracy: 98.4848%
# Epoch 10/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-969846779.py in <cell line: 0>()
#      69                     # Training
#      70                     print("Training...")
# ---> 71                     trainer.fit(num_epochs=100)
#      72
#      73                     # Evaluate
#
# /tmp/ipython-input-3526298778.py in fit(self, num_epochs)
#      13         for epoch in range(num_epochs):
#      14             print(f'Epoch {epoch + 1}/{num_epochs}')
# ---> 15             train_loss, train_accuracy = self.train_one_epoch()
#      16             val_loss, val_accuracy = self.validate_one_epoch()
#      17             print(
#
# /tmp/ipython-input-3526298778.py in train_one_epoch(self)
#      30             outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
#      31             loss = self.criterion(outputs, labels)
# ---> 32             loss.backward()
#      33             self.optimizer.step()
#      34
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     827         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828     try:
# --> 829         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830             t_outputs, *args, **kwargs
#     831         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# # Give your answer here.
#
# (i) What is your best model?
#
# (ii) The accuracy of your best model on the test set
#
# (iii) The values of the hyperparameters of your best model
#
# (iv) The link to download your best model

# %% [markdown]
# (i) prefix_best_model
#
# (ii) 0.9900
#
# (iii) Prefix Length: 10, Learning Rate: 0.01, Optimizer: AdamW, Weight Decay: 0.01, Dropout: 0.1

# %% [markdown]
# ---
# <div style="text-align: center"> <font color="green">GOOD LUCK WITH YOUR ASSIGNMENT 2!</font> </div>
# <div style="text-align: center"> <font color="black">END OF ASSIGNMENT</font> </div>
